# %% [markdown]
# # Relatório de Análise VI

# %% [markdown]
# ## Criando Novas Variáveis

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep=';')

# %%
dados.head(20)
# Out:
#            Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 0     Quitinete               Copacabana        1      0       0    40
# 1   Apartamento                   Centro        1      0       0    15
# 2   Apartamento                 Cachambi        2      0       0    50
# 3   Apartamento                   Grajaú        2      1       0    70
# 4   Apartamento      Lins de Vasconcelos        3      1       1    90
# 5   Apartamento               Copacabana        1      0       1    40
# 6   Apartamento               Copacabana        4      3       1   243
# 7   Apartamento  Freguesia (Jacarepaguá)        3      0       0    54
# 8   Apartamento          Barra da Tijuca        2      1       1    67
# 9   Apartamento                   Tijuca        2      1       0   110
# 10  Apartamento                  Ipanema        3      1       1   125
# 11  Apartamento                   Tijuca        1      0       0    48
# 12  Apartamento          Barra da Tijuca        3      3       1   175
# 13  Apartamento               Copacabana        3      1       2   378
# 14  Apartamento               Copacabana        3      0       0   180
# 15  Apartamento                   Leblon        3      1       0   110
# 16    Quitinete               Copacabana        1      0       0    27
# 17  Apartamento          Jardim Oceânico        3      3       1   200
# 18  Apartamento          Barra da Tijuca        3      1       2    70
# 19  Apartamento               Copacabana        4      1       0   244
#
#       Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0    1700.0       500.0    60.0     42.50   Apartamento
# 1     800.0       390.0    20.0     53.33   Apartamento
# 2    1300.0       301.0    17.0     26.00   Apartamento
# 3    1500.0       642.0    74.0     21.43   Apartamento
# 4    1500.0       455.0    14.0     16.67   Apartamento
# 5    2000.0       561.0    50.0     50.00   Apartamento
# 6   13000.0      2000.0   803.0     53.50   Apartamento
# 7     950.0       300.0    28.0     17.59   Apartamento
# 8    1700.0       589.0   147.0     25.37   Apartamento
# 9    1900.0       700.0   138.0     17.27   Apartamento
# 10   7000.0      2100.0   463.0     56.00   Apartamento
# 11    750.0       772.0    25.0     15.62   Apartamento
# 12   4200.0      1500.0   500.0     24.00   Apartamento
# 13  10000.0      2150.0   700.0     26.46   Apartamento
# 14   5500.0      1780.0   420.0     30.56   Apartamento
# 15   3900.0      1500.0   120.0     35.45   Apartamento
# 16   1300.0       380.0    53.0     48.15   Apartamento
# 17   3500.0      1780.0   496.0     17.50   Apartamento
# 18   1800.0      1095.0   140.0     25.71   Apartamento
# 19   5000.0      2500.0  4100.0     20.49   Apartamento

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['IPTU'] + dados['Condominio']

# %%
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 0    Quitinete               Copacabana        1      0       0    40
# 1  Apartamento                   Centro        1      0       0    15
# 2  Apartamento                 Cachambi        2      0       0    50
# 3  Apartamento                   Grajaú        2      1       0    70
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90
# 5  Apartamento               Copacabana        1      0       1    40
# 6  Apartamento               Copacabana        4      3       1   243
# 7  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54
# 8  Apartamento          Barra da Tijuca        2      1       1    67
# 9  Apartamento                   Tijuca        2      1       0   110
#
#      Valor  Condominio   IPTU  Valor m2 Tipo Agregado  Valor Bruto
# 0   1700.0       500.0   60.0     42.50   Apartamento       2260.0
# 1    800.0       390.0   20.0     53.33   Apartamento       1210.0
# 2   1300.0       301.0   17.0     26.00   Apartamento       1618.0
# 3   1500.0       642.0   74.0     21.43   Apartamento       2216.0
# 4   1500.0       455.0   14.0     16.67   Apartamento       1969.0
# 5   2000.0       561.0   50.0     50.00   Apartamento       2611.0
# 6  13000.0      2000.0  803.0     53.50   Apartamento      15803.0
# 7    950.0       300.0   28.0     17.59   Apartamento       1278.0
# 8   1700.0       589.0  147.0     25.37   Apartamento       2436.0
# 9   1900.0       700.0  138.0     17.27   Apartamento       2738.0

# %%
dados['Valor m2'] = dados['Valor'] / dados['Area']

# %%
dados.head(5)
# Out:
#           Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete           Copacabana        1      0       0    40  1700.0
# 1  Apartamento               Centro        1      0       0    15   800.0
# 2  Apartamento             Cachambi        2      0       0    50  1300.0
# 3  Apartamento               Grajaú        2      1       0    70  1500.0
# 4  Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
#
#    Condominio  IPTU   Valor m2 Tipo Agregado  Valor Bruto
# 0       500.0  60.0  42.500000   Apartamento       2260.0
# 1       390.0  20.0  53.333333   Apartamento       1210.0
# 2       301.0  17.0  26.000000   Apartamento       1618.0
# 3       642.0  74.0  21.428571   Apartamento       2216.0
# 4       455.0  14.0  16.666667   Apartamento       1969.0

# %%
dados['Valor m2'] = dados['Valor m2'].round(2)

# %%
dados.head(4)
# Out:
#           Tipo      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0    Quitinete  Copacabana        1      0       0    40  1700.0       500.0
# 1  Apartamento      Centro        1      0       0    15   800.0       390.0
# 2  Apartamento    Cachambi        2      0       0    50  1300.0       301.0
# 3  Apartamento      Grajaú        2      1       0    70  1500.0       642.0
#
#    IPTU  Valor m2 Tipo Agregado  Valor Bruto
# 0  60.0     42.50   Apartamento       2260.0
# 1  20.0     53.33   Apartamento       1210.0
# 2  17.0     26.00   Apartamento       1618.0
# 3  74.0     21.43   Apartamento       2216.0

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto'] / dados['Area']).round(2)

# %%
dados.head(3)
# Out:
#           Tipo      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0    Quitinete  Copacabana        1      0       0    40  1700.0       500.0
# 1  Apartamento      Centro        1      0       0    15   800.0       390.0
# 2  Apartamento    Cachambi        2      0       0    50  1300.0       301.0
#
#    IPTU  Valor m2 Tipo Agregado  Valor Bruto  Valor Bruto m2
# 0  60.0     42.50   Apartamento       2260.0           56.50
# 1  20.0     53.33   Apartamento       1210.0           80.67
# 2  17.0     26.00   Apartamento       1618.0           32.36

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
dados
# Out:
#                      Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0               Quitinete            Copacabana        1      0       0    40
# 1             Apartamento                Centro        1      0       0    15
# 2             Apartamento              Cachambi        2      0       0    50
# 3             Apartamento                Grajaú        2      1       0    70
# 4             Apartamento   Lins de Vasconcelos        3      1       1    90
# ...                   ...                   ...      ...    ...     ...   ...
# 15680  Casa de Condomínio       Barra da Tijuca        5      3       4   450
# 15681         Apartamento                 Méier        2      0       0    70
# 15682           Quitinete                Centro        0      0       0    27
# 15683         Apartamento           Jacarepaguá        3      1       2    78
# 15684         Apartamento  São Francisco Xavier        2      1       0    48
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado  Valor Bruto  \
# 0       1700.0       500.0    60.0     42.50   Apartamento       2260.0
# 1        800.0       390.0    20.0     53.33   Apartamento       1210.0
# 2       1300.0       301.0    17.0     26.00   Apartamento       1618.0
# 3       1500.0       642.0    74.0     21.43   Apartamento       2216.0
# 4       1500.0       455.0    14.0     16.67   Apartamento       1969.0
# ...        ...         ...     ...       ...           ...          ...
# 15680  15000.0      1711.0  2332.0     33.33          Casa      19043.0
# 15681    900.0       490.0    48.0     12.86   Apartamento       1438.0
# 15682    800.0       350.0    25.0     29.63   Apartamento       1175.0
# 15683   1800.0       800.0    40.0     23.08   Apartamento       2640.0
# 15684   1400.0       509.0    37.0     29.17   Apartamento       1946.0
#
#        Valor Bruto m2
# 0               56.50
# 1               80.67
# 2               32.36
# 3               31.66
# 4               21.88
# ...               ...
# 15680           42.32
# 15681           20.54
# 15682           43.52
# 15683           33.85
# 15684           40.54
#
# [15685 rows x 13 columns]

# %% [markdown]
# # Excluindo Variáveis

# %%
dados_aux = pd.DataFrame(dados[['Tipo Agregado', 'Valor m2', 'Valor Bruto', 'Valor Bruto m2']])

# %%
dados_aux.head(10)
# Out:
#   Tipo Agregado  Valor m2  Valor Bruto  Valor Bruto m2
# 0   Apartamento     42.50       2260.0           56.50
# 1   Apartamento     53.33       1210.0           80.67
# 2   Apartamento     26.00       1618.0           32.36
# 3   Apartamento     21.43       2216.0           31.66
# 4   Apartamento     16.67       1969.0           21.88
# 5   Apartamento     50.00       2611.0           65.28
# 6   Apartamento     53.50      15803.0           65.03
# 7   Apartamento     17.59       1278.0           23.67
# 8   Apartamento     25.37       2436.0           36.36
# 9   Apartamento     17.27       2738.0           24.89

# %%
del dados_aux['Valor Bruto']

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2  Valor Bruto m2
# 0       Apartamento     42.50           56.50
# 1       Apartamento     53.33           80.67
# 2       Apartamento     26.00           32.36
# 3       Apartamento     21.43           31.66
# 4       Apartamento     16.67           21.88
# ...             ...       ...             ...
# 15680          Casa     33.33           42.32
# 15681   Apartamento     12.86           20.54
# 15682   Apartamento     29.63           43.52
# 15683   Apartamento     23.08           33.85
# 15684   Apartamento     29.17           40.54
#
# [15685 rows x 3 columns]

# %%
dados_aux.pop('Valor Bruto m2')
# Out:
# 0        56.50
# 1        80.67
# 2        32.36
# 3        31.66
# 4        21.88
#          ...
# 15680    42.32
# 15681    20.54
# 15682    43.52
# 15683    33.85
# 15684    40.54
# Name: Valor Bruto m2, Length: 15685, dtype: float64

# %%
dados_aux.head(10)

# %%
dados.drop(['Valor Bruto', 'Valor Bruto m2'], axis=1, inplace=True)

# %%
dados.head(10)

# %%
dados.to_csv('dados/aluguel_residencial.csv', sep=';', index=False)
